# %% [markdown]
# # Exploración de datos

# %% [markdown]
# Estas cadenas de texto son cartas de recordatorio de deudas pendientes por el adeudo de un préstamo para la compra de un automóvil de lujo. Las deudas son en diferentes monedas y se menciona que hay intentos de contacto y recordatorios previos que no han sido respondidos. Se solicita que se devuelva el automóvil o se cancele la deuda total lo antes posible, y se ofrecen opciones de arreglos de pago en caso de dificultades financieras. También se mencionan las empresas y la información de contacto de las empresas que emitieron el préstamo.

# %% [markdown]
# En estos textos se presentan algunos patrones comunes:
#
# 1. Las cartas están dirigidas a una persona en particular y mencionan su nombre completo.
#
# 2. Se menciona que hay una deuda pendiente en la cuenta de la persona con una empresa específica.
#
# 3. Se menciona el monto de la deuda y la moneda en la que está expresada.
#
# 4. Se menciona que se ha intentado ponerse en contacto con la persona y recordarle la deuda pendiente, pero no se ha recibido respuesta ni pago.
#
# 5. Se solicita que se devuelva el automóvil o se cancele la deuda total lo antes posible.
#
# 6. Se ofrecen opciones de arreglos de pago en caso de dificultades financieras.
#
# 7. Se menciona la empresa y se proporciona información de contacto.
#
# 8. se menciona la ciudad donde se toma el carro

# %%
# importar librearias
import pandas as pd
import numpy as np
import datetime as dt
import spacy

# %%
#leer un archivo csv delimitado por | y con codificacion utf-8
df = pd.read_csv('documentos.csv', sep='|', encoding='utf-8')
print(df.head())
# Out:
#    document_name                                           document
# 0             86    Señor/señora: Daniel Roberto Torres Gómez  L...
# 1            470    Atención: Ana Miguel Jiménez Rodríguez  Le e...
# 2             16    Oiga!!!! Juan Pablo Fernández Muñoz  Esperam...
# 3            165    Querido/a Carlos Miguel Pérez Pérez,  Espera...
# 4            114    Estimadisimo/a Daniel Cristina Rodríguez Gon...

# %%
# Obtenemos información básica del conjunto de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   document_name  499 non-null    int64
#  1   document       499 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
# Cargar el modelo de lenguaje de spaCy
nlp = spacy.load("es_core_news_lg")

# %%
# Creamos una lista vacía para almacenar los tokens
tokens = []

# Iteramos sobre cada fila del dataframe
for index, row in df.iterrows():
    # Procesamos el texto de la columna "texto" utilizando spacy
    doc = nlp(row['document'])
    # Añadimos los tokens a la lista
    tokens.extend([token.text for token in doc])

# Contamos la frecuencia de cada token
frequencies = pd.Series(tokens).value_counts()

print(frequencies)
# Out:
# de                  5598
# ,                   4133
# .                   3930
#                     3222
#                     3050
#                     ...
# 8,168,370,417.16       1
# 5246184                1
# 09/15/2017             1
# 6,360,534,685.37       1
# 6803552                1
# Length: 2201, dtype: int64

# %%
# cuantas veces a aparece el nombre de una ciudad en cada fila del conjunto de datos 
for index, row in df.iterrows():
    doc = nlp(row['document'])
    #mostrar cuantas veces aparece el nombre de una ciudad en cada fila del conjunto de datos
    print("Ciudades en el documento", index, ":", [(X.text, X.label_) for X in doc.ents if X.label_ == "LOC"])
# Out:
# Ciudades en el documento 0 : [('Zaragoza', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 1 : [('San Andrés.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 2 : [('Nos', 'LOC'), ('Girón', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 3 : [('Nos', 'LOC'), ('Popayán', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 4 : [('Puerto Leguízamo.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 5 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 6 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 7 : [('Ibagué', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 8 : [('Montelíbano.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 9 : [('Initech', 'LOC'), ('Pasto', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 10 : [('Pamplona', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 11 : [('Planeta Rica', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 12 : [('Cartagena', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 13 : [('Ibagué', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.com.co', 'LOC')]
# Ciudades en el documento 14 : [('Palmira.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 15 : [('Bucaramanga', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 16 : [('Riohacha', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 17 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 18 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 19 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 20 : [('Tumaco', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 21 : [('Itagüí', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 22 : [('Cartagena', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.jdm_enterprises.org.co', 'LOC')]
# Ciudades en el documento 23 : [('Manizales', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.net.co', 'LOC')]
# Ciudades en el documento 24 : [('San Andrés', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 25 : [('Tame', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 26 : [('Bucaramanga', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 27 : [('Bogotá', 'LOC'), ('Colombia  Website www.initech.co', 'LOC')]
# Ciudades en el documento 28 : [('Chinú.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 29 : [('Yarumal', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 30 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 31 : [('Zaragoza', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 32 : [('Sonson.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 33 : [('Villavicencio', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 34 : [('Ciénaga.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 35 : [('Barranquilla', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 36 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 37 : [('Sahagún', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 38 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 39 : [('Nos', 'LOC'), ('Soledad', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 40 : [('Soacha', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 41 : [('Ciénaga de Oro', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.net.co', 'LOC')]
# Ciudades en el documento 42 : [('Manizales', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 43 : [('Pasto', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 44 : [('Chima', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 45 : [('Nos', 'LOC'), ('Ibagué', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 46 : [('Nos', 'LOC'), ('Dosquebradas', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 47 : [('San Carlos', 'LOC'), ('Initech    Domicilio Calle', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 48 : [('Sahagún.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 49 : [('Valledupar.', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 50 : [('Chinú', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.jdm_enterprises.org.co', 'LOC')]
# Ciudades en el documento 51 : [('Fonseca', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 52 : [('Cartagena', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 53 : [('Nos', 'LOC'), ('Neiva', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 54 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 55 : [('Bucaramanga', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 56 : [('Armenia', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 57 : [('Nos', 'LOC'), ('Valledupar', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 58 : [('San Pelayo.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 59 : [('Nos', 'LOC'), ('ciudad de Tierralta', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 60 : [('Cereté.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 61 : [('Nos', 'LOC'), ('Montería', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 62 : [('Ocana', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.net.co', 'LOC')]
# Ciudades en el documento 63 : [('Mocoa', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 64 : [('Cúcuta', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 65 : [('Itagüí.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 66 : [('Santa Marta.', 'LOC'), ('Initech    Domicilio Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 67 : [('Chiriguaná.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 68 : [('Canalete.', 'LOC'), ('Globex Industries', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 69 : [('Envigado.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 70 : [('Montelíbano', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 71 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 72 : [('Valledupar.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 73 : [('Nos', 'LOC'), ('Riohacha', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 74 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 75 : [('San Pelayo.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 76 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 77 : [('Riohacha.', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 78 : [('Bogotá', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 79 : [('Tarazá', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 80 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 81 : [('Medellín', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 82 : [('Nos', 'LOC'), ('Mocoa', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 83 : [('Riohacha', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 84 : [('Mocoa.', 'LOC'), ('Initech', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 85 : [('Sonson.', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 86 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 87 : [('Initech    Domicilio Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 88 : [('Nos', 'LOC'), ('Tumaco', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 89 : [('Lorica.', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 90 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 91 : [('Tumaco.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 92 : [('Ciénaga de Oro', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 93 : [('Chinú.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 94 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 95 : [('Los Córdobas', 'LOC'), ('Globex Industries', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 96 : [('Nos', 'LOC'), ('Ibagué', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 97 : [('San José del Guaviare', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 98 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 99 : [('La Apartada', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 100 : [('Nos', 'LOC'), ('Planeta Rica', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 101 : [('Bogotá', 'LOC')]
# Ciudades en el documento 102 : [('Planeta Rica', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 103 : [('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 104 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 105 : [('Puerto Leguízamo', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 106 : [('Nos', 'LOC'), ('Ciénaga', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 107 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 108 : [('INR', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 109 : [('Nos', 'LOC'), ('Cartagena', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 110 : [('San Bernardo del Viento', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.net.co', 'LOC')]
# Ciudades en el documento 111 : [('Yarumal.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 112 : [('Valledupar', 'LOC'), ('Domicilio Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 113 : [('Initech  Dirección Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.acme_corp.net.co', 'LOC')]
# Ciudades en el documento 114 : [('Bogotá', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 115 : [('Cartagena', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 116 : [('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 117 : [('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 118 : [('Cúcuta', 'LOC'), ('Initech    Domicilio Avenida', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 119 : [('Puerto Asís', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 120 : [('Cereté.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 121 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 122 : [('Nos', 'LOC'), ('Riohacha', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 123 : [('Barranquilla.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 124 : [('Pasto', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 125 : [('Montelíbano', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 126 : [('Nos', 'LOC'), ('Chinú', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 127 : [('El Bagre', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 128 : [('Montería', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 129 : [('Sahagún', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 130 : [('Planeta Rica', 'LOC'), ('Initech    Domicilio Avenida', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 131 : [('La Estrella', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 132 : [('Initech', 'LOC'), ('San Andrés de Sotavento', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 133 : [('Ciénaga.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 134 : [('Ipiales', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 135 : [('Nos', 'LOC'), ('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 136 : [('Ayapel.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 137 : [('Armenia', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 138 : [('Nos', 'LOC'), ('Manizales', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 139 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 140 : [('Cereté', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 141 : [('Yarumal.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 142 : [('Chinú.', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 143 : [('Canalete', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 144 : [('Dosquebradas.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 145 : [('Bogotá', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 146 : [('Los Córdobas', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 147 : [('Pamplona', 'LOC'), ('Globex Industries', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 148 : [('Soacha', 'LOC'), ('Initech', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 149 : [('Yopal', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 150 : [('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 151 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 152 : [('Soledad', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 153 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 154 : [('Purificación', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 155 : [('Palmira', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 156 : [('Tunja', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 157 : [('Pamplona', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 158 : [('San José del Guaviare', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 159 : [('Mocoa', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 160 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 161 : [('Ipiales', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 162 : [('Nos', 'LOC'), ('Sabaneta', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 163 : [('Puerto Asís', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 164 : [('La Apartada', 'LOC'), ('Globex Industries', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 165 : [('Nos', 'LOC'), ('San José del Guaviare', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 166 : [('Puerto Libertador', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 167 : [('Ciénaga de Oro', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 168 : [('Pereira.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 169 : [('Valledupar.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 170 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 171 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 172 : [('Bogotá', 'LOC')]
# Ciudades en el documento 173 : [('Montería', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.org.co', 'LOC')]
# Ciudades en el documento 174 : [('Villavicencio', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 175 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 176 : [('Itagüí', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 177 : [('Tumaco.  ', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 178 : [('Riohacha', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 179 : [('Nos', 'LOC'), ('Los Córdobas', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 180 : [('Girón', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 181 : [('Ayapel', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 182 : [('Nos', 'LOC'), ('Lorica', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 183 : [('Bogotá', 'LOC'), ('Colombia  Website www.initech.co', 'LOC')]
# Ciudades en el documento 184 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 185 : [('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 186 : [('Tunja', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 187 : [('Puerto Asís', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 188 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 189 : [('Nos', 'LOC'), ('Fonseca', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 190 : [('Nos', 'LOC'), ('Mocoa', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 191 : [('Sabaneta', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 192 : [('Nos', 'LOC'), ('Sabaneta', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 193 : [('Valledupar', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 194 : [('Initech  Dirección Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 195 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 196 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 197 : [('Cartagena', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 198 : [('Nos', 'LOC'), ('Barranquilla', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 199 : [('Barranquilla', 'LOC'), ('Domicilio Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 200 : [('Nos', 'LOC'), ('Tierralta', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 201 : [('Montería.  ', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 202 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 203 : [('Tarazá.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 204 : [('Nos', 'LOC'), ('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 205 : [('Nos', 'LOC'), ('Popayán', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 206 : [('Ciénaga de Oro', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 207 : [('Bello', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 208 : [('San Andrés de Sotavento.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 209 : [('Ciénaga de Oro', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 210 : [('Nos', 'LOC'), ('Montelíbano', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 211 : [('Nos', 'LOC'), ('Fonseca', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 212 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 213 : [('815,663,270.94', 'LOC'), ('Cereté.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 214 : [('Nos', 'LOC'), ('Cartagena', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 215 : [('Tunja', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 216 : [('8,053,665,849.74', 'LOC'), ('Lorica', 'LOC'), ('Domicilio Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 217 : [('Dosquebradas.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 218 : [('Initech', 'LOC'), ('Armenia', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 219 : [('Montería', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 220 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 221 : [('Pamplona', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 222 : [('Nos', 'LOC'), ('Sincelejo', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 223 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 224 : [('Neiva', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 225 : [('Mocoa', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 226 : [('Nos', 'LOC'), ('Puerto Leguízamo', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 227 : [('Tumaco', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 228 : [('San Andrés de Sotavento.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 229 : [('Nos', 'LOC'), ('Girardot', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 230 : [('Nos', 'LOC'), ('Fonseca', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 231 : [('Pasto', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 232 : [('Yarumal', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 233 : [('Girón', 'LOC'), ('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 234 : [('Tunja', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 235 : [('Pamplona', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 236 : [('Nos', 'LOC'), ('ciudad de Tierralta', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 237 : [('Sabaneta', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 238 : [('Mocoa', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.com.co', 'LOC')]
# Ciudades en el documento 239 : [('Medellín', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 240 : [('Chinú', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 241 : [('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 242 : [('Nos', 'LOC'), ('Neiva', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 243 : [('Nos', 'LOC'), ('Cali', 'LOC'), ('Initech  ubicada Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 244 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 245 : [('Tumaco.', 'LOC'), ('Initech', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 246 : [('5,886,075,516.25', 'LOC'), ('San Andrés de Sotavento', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 247 : [('San Andrés', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 248 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 249 : [('Santa Marta.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 250 : [('Saravena.  ', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 251 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 252 : [('Nos', 'LOC'), ('Ocana', 'LOC'), ('Initech  ubicada Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 253 : [('INR', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 254 : [('La Estrella', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 255 : [('Zaragoza', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 256 : [('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 257 : [('Medellín', 'LOC'), ('Initech', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 258 : [('Nos', 'LOC'), ('Buenavista', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 259 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 260 : [('Chinú.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 261 : [('Canalete.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 262 : [('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.net.co', 'LOC')]
# Ciudades en el documento 263 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 264 : [('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 265 : [('Ibagué', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 266 : [('Initech  Dirección Avenida', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 267 : [('Ciénaga de Oro', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 268 : [('Nos', 'LOC'), ('San José del Guaviare', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 269 : [('Chinú.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 270 : [('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.com.co', 'LOC')]
# Ciudades en el documento 271 : [('Ayapel', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 272 : [('Montería.  ', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 273 : [('La Apartada', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 274 : [('Montería', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 275 : [('Nos', 'LOC'), ('Sabaneta', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 276 : [('Montería.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 277 : [('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 278 : [('Initech  Localizacion Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 279 : [('Girardot', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 280 : [('Cartagena', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 281 : [('Montería.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 282 : [('Initech  Localizacion Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 283 : [('Nos', 'LOC'), ('Ibagué', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 284 : [('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 285 : [('Tame.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 286 : [('Tunja.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 287 : [('Los Córdobas', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 288 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 289 : [('Puerto Libertador', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 290 : [('Bello', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 291 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 292 : [('El Bagre.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 293 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 294 : [('Fonseca.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 295 : [('Bucaramanga', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 296 : [('Ciénaga de Oro', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 297 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 298 : [('Initech    Domicilio Calle', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 299 : [('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 300 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 301 : [('Tame.', 'LOC'), ('Globex Industries', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 302 : [('Nos', 'LOC'), ('Envigado', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 303 : [('Sabaneta', 'LOC'), ('Globex Industries', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 304 : [('Nos', 'LOC'), ('Fonseca', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 305 : [('Tuluá.', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 306 : [('Nos', 'LOC'), ('Villavicencio', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 307 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 308 : [('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 309 : [('Chima', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 310 : [('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 311 : [('Initech  Localizacion Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 312 : [('Villavicencio', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 313 : [('Montería', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 314 : [('Chima', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 315 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 316 : [('Tame', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 317 : [('Nos', 'LOC'), ('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 318 : [('Ciénaga.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 319 : [('Initech  Localizacion Avenida', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 320 : [('Barranquilla', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 321 : [('Initech', 'LOC'), ('Ciénaga', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 322 : [('Valledupar.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 323 : [('Yarumal.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 324 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 325 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 326 : [('Bucaramanga.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 327 : [('Barranquilla.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 328 : [('Tierralta', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 329 : [('Valledupar.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 330 : [('Cali', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 331 : [('Barranquilla.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 332 : [('Chinú', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 333 : [('Bogotá', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 334 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 335 : [('Nos', 'LOC'), ('Pasto', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 336 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 337 : [('San Andrés de Sotavento', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 338 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 339 : [('Valledupar', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.com.co', 'LOC')]
# Ciudades en el documento 340 : [('Ciénaga de Oro', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 341 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 342 : [('Itagüí.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 343 : [('Aguazul.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 344 : [('Yarumal.', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 345 : [('Nos', 'LOC'), ('Cartagena', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 346 : [('Tuluá.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 347 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 348 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 349 : [('Nos', 'LOC'), ('Montería', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 350 : [('Puerto Asís', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 351 : [('Nos', 'LOC'), ('San Antero', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 352 : [('Initech    Domicilio Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 353 : [('Nos', 'LOC'), ('Riohacha', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 354 : [('Initech', 'LOC'), ('San Andrés de Sotavento', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 355 : [('San Carlos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 356 : [('Aguazul.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 357 : [('Puerto Escondido.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 358 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 359 : [('Initech  Dirección Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 360 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 361 : [('Puerto Libertador', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 362 : [('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 363 : [('Nos', 'LOC'), ('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 364 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 365 : [('Initech    Domicilio Carrera', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 366 : [('Bogotá', 'LOC')]
# Ciudades en el documento 367 : [('Soledad', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 368 : [('Cali', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 369 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 370 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 371 : [('Canalete.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 372 : [('Santa Marta', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 373 : [('Chinú.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 374 : [('Riohacha', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 375 : [('Puerto Asís', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 376 : [('Bogotá', 'LOC')]
# Ciudades en el documento 377 : [('Nos', 'LOC'), ('Canalete', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 378 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 379 : [('Bogotá', 'LOC')]
# Ciudades en el documento 380 : [('Cereté.', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 381 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 382 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 383 : [('Montería', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 384 : [('Dosquebradas.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 385 : [('Nos', 'LOC'), ('Chinú', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 386 : [('Valledupar.', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 387 : [('San Carlos', 'LOC'), ('Initech  Dirección Avenida', 'LOC'), ('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC'), ('www.presto_logistics.org.co', 'LOC')]
# Ciudades en el documento 388 : [('Nos', 'LOC'), ('Chiriguaná', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 389 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 390 : [('Sonson.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 391 : [('Sonson.', 'LOC'), ('Globex Industries', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 392 : [('Cúcuta', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 393 : [('Valledupar', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.com.co', 'LOC')]
# Ciudades en el documento 394 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 395 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 396 : [('Pamplona', 'LOC'), ('Initech', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 397 : [('Villavicencio', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 398 : [('Tuluá.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 399 : [('Nos', 'LOC'), ('Saravena', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 400 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 401 : [('Valledupar.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 402 : [('Neiva', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.acme_corp.org.co', 'LOC')]
# Ciudades en el documento 403 : [('Girón', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 404 : [('Lorica.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 405 : [('Nos', 'LOC'), ('San Andrés de Sotavento', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 406 : [('Ciénaga de Oro', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 407 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 408 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 409 : [('Envigado', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.co', 'LOC')]
# Ciudades en el documento 410 : [('Nos', 'LOC'), ('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 411 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 412 : [('Arauca', 'LOC'), ('Initech', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 413 : [('Nos', 'LOC'), ('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 414 : [('Nos', 'LOC'), ('Chiriguaná', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 415 : [('Pasto', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 416 : [('Nos', 'LOC'), ('San Carlos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 417 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 418 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 419 : [('Nos', 'LOC'), ('Ciénaga de Oro', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 420 : [('Yopal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 421 : [('San Andrés de Sotavento', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 422 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 423 : [('Aguazul.', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 424 : [('Bogotá', 'LOC'), ('Colombia  Website www.initech.co', 'LOC')]
# Ciudades en el documento 425 : [('Puerto Libertador', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.net.co', 'LOC')]
# Ciudades en el documento 426 : [('San Pelayo', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 427 : [('Tarazá', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 428 : [('Ibagué', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 429 : [('Los Córdobas', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 430 : [('Nos', 'LOC'), ('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 431 : [('Tuluá', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.jdm_enterprises.org.co', 'LOC')]
# Ciudades en el documento 432 : [('Yopal', 'LOC'), ('Initech', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 433 : [('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 434 : [('Nos', 'LOC'), ('Medellín', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 435 : [('Initech', 'LOC'), ('Montería', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 436 : [('Arauca', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.initech.com.co', 'LOC')]
# Ciudades en el documento 437 : [('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 438 : [('Ibagué', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 439 : [('Buenavista', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 440 : [('Bucaramanga.', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 441 : [('San José del Guaviare', 'LOC'), ('Initech', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 442 : [('Globex Industries', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 443 : [('Tarazá', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 444 : [('Valledupar', 'LOC'), ('Domicilio Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 445 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 446 : [('Buenaventura', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 447 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 448 : [('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 449 : [('Sincelejo.', 'LOC'), ('Initech    Domicilio Avenida', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 450 : [('Puerto Asís', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 451 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 452 : [('Tunja.', 'LOC'), ('Initech    Domicilio Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 453 : [('2014-03-23  Fake Incorporated', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 454 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 455 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 456 : [('Nos', 'LOC'), ('Soledad', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 457 : [('Nos', 'LOC'), ('Chima', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 458 : [('Nos', 'LOC'), ('Yarumal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 459 : [('Cereté', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 460 : [('Tunja.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 461 : [('Nos', 'LOC'), ('Valledupar', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 462 : [('Nos', 'LOC'), ('Ipiales', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 463 : [('Cúcuta', 'LOC'), ('Initech, ubicada Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 464 : [('Purificación', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 465 : [('Villavicencio.', 'LOC'), ('Initech', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 466 : [('La Apartada', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 467 : [('Chinú', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 468 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 469 : [('Initech    Domicilio Calle', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 470 : [('Nos', 'LOC'), ('Ciénaga de Oro', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 471 : [('Tunja.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 472 : [('Nos', 'LOC'), ('Saravena', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 473 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 474 : [('Momil.', 'LOC'), ('Callejón', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 475 : [('Yarumal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.co', 'LOC')]
# Ciudades en el documento 476 : [('Yopal', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 477 : [('San José del Guaviare', 'LOC'), ('Globex Industries', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 478 : [('Zaragoza', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 479 : [('Valledupar.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 480 : [('Tunja.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 481 : [('Pereira.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 482 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 483 : [('Ocana.', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 484 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 485 : [('La Apartada', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.globex_industries.com.co', 'LOC')]
# Ciudades en el documento 486 : [('Sincelejo.', 'LOC'), ('Initech    Domicilio Calle', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 487 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 488 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 489 : [('Initech', 'LOC'), ('Ocana', 'LOC'), ('Initech', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 490 : [('Bogotá', 'LOC'), ('Colombia  Teléfono', 'LOC')]
# Ciudades en el documento 491 : [('Villavicencio.', 'LOC'), ('Diagonal', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 492 : [('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 493 : [('Nos', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 494 : [('Pasto', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC'), ('www.presto_logistics.com.co', 'LOC')]
# Ciudades en el documento 495 : [('Initech  Localizacion Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 496 : [('Nos', 'LOC'), ('Puerto Asís', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 497 : [('Nos', 'LOC'), ('Tuluá', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]
# Ciudades en el documento 498 : [('Nos', 'LOC'), ('Riohacha', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]

# %%
#mostrar la primeta fila de df en document
df['document'][113]
# palabra Purificación. de municipio de Purificación no de la palabra purificación
# Out:
# '  Atención: Ana Samantha Álvarez Torres  Le escribimos para informarle que tiene un saldo a favor nuestro de COP 6,153,364,378.31 en su cuenta con nuestra empresa. Como puede recordar, tomó un préstamo con nosotros para   adquirir un auto de lujo Ferrari Aventador en Purificación. A pesar de múltiples intentos de ponerse en contacto con usted y recordarle su deuda pendiente, no hemos recibido ninguna respuesta   ni pago de su parte. Por lo tanto, solicitamos que devuelva el auto a nosotros o pague la totalidad de su deuda lo antes posible. Si no toma medidas en este asunto,   nos veremos obligados a iniciar acciones legales para recuperar la totalidad de su deuda.     Le instamos a que se ponga en contacto con nosotros lo antes posible para   discutir acuerdos de pago y evitar acciones legales adicionales, su deuda esta desde el 2015-09-25.     Si está experimentando dificultades financieras y no puede pagar la   totalidad de su deuda en este momento, no dude en ponerse en contacto con nosotros para discutir acuerdos de pago. Estamos dispuestos a trabajar con usted para   encontrar una solución justa y razonable para ambas partes.  Esperamos tener noticias suyas pronto y organizar una sesión de yoga y meditación colectiva para calmar los ánimos y encontrar una solución sana y equilibrada a este asunto.  Fake Incorporated quiere recordarle de manera amistosa que es hora de ponerse al día con sus pagos. ¡No se preocupe, tenemos muchas opciones   para ayudarle a encontrar una solución que funcione para usted!    Gracias por su atención oportuna a este asunto.  Initech  Dirección Diagonal espejismo 101112, Bogotá, Colombia  Teléfono +57 383 1934924  website www.acme_corp.net.co    '

# %%
#cual es la probabilidad encontrar el nombre de la ciudad al inicio de la cadena de texto
doc = nlp(df['document'][7])
print([(X.text , X.label_) for X in doc.ents if X.label_ == "LOC"])
# Out:
# [('Ibagué', 'LOC'), ('Calle falsa 123', 'LOC'), ('Bogotá', 'LOC'), ('Colombia', 'LOC')]

# %% [markdown]
# En el análisis y observación de los datos, se evidenciaron patrones como encontrar el valor de la ciudad al inicio de la cadena de texto, seguido del tipo de auto. Al tener la ciudad en primer orden, se optó por buscar el primer valor y guardarlo en el dataframe.
