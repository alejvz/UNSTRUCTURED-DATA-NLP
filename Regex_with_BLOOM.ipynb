# %% [markdown]
# <a href="https://colab.research.google.com/github/alejvz/UNSTRUCTURED-DATA-NLP/blob/master/Regex_with_BLOOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 4.4 MB 28.3 MB/s
#      |████████████████████████████████| 596 kB 49.3 MB/s
#      |████████████████████████████████| 101 kB 12.5 MB/s
#      |████████████████████████████████| 6.6 MB 56.6 MB/s

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %%
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b3", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b3")
# Out:
# Downloading:   0%|          | 0.00/732 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.21G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/199 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.8M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
set_seed(424242)

# %%
 model.__class__.__name__
# Out:
# 'BloomForCausalLM'

# %%
prompt = 'python function to extract floating points from text \n import re \n re.findall('

# %%
input_ids = tokenizer(prompt, return_tensors="pt").to(0)

# %%
sample = model.generate(**input_ids, max_length=50, top_k=0, temperature=0.7)

# %%
print(tokenizer.decode(sample[0], truncate_before_pattern=[r"\n\n^#", "^'''", "\n\n\n"]))
# Out:
# python function to extract floating points from text
#  import re
#  re.findall(r'(\d+\.\d*)', text) # extract float values from text
#
# A:
#
# You can use re.findall to find the float values in the

# %%
text = 'this is amazing nong 2.2 3.4'

# %%
import re 
re.findall(r'(\d+\.\d*)', text)
# Out:
# ['2.2', '3.4']
